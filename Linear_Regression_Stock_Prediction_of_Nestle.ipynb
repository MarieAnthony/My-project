# %% [markdown]
# <a href="https://colab.research.google.com/github/MarieAnthony/My-project/blob/main/Linear_Regression_Stock_Prediction_of_Nestle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <div class="alert alert-block alert-info"> <span style="font-family: Times New Roman">Linear Regression </span> </div>

# %% [markdown]
# ### <div class="alert alert-block alert-success"> <span  style= "font-family: Times New Roman">**Objective:** Nestle India Historical Stock Price to Predict the Close Price</span> </div>

# %% [markdown]
# Download the dataset from here: <br>
# Click here: <br>
# <a href='https://drive.google.com/file/d/1cXuGM0Xm10sQnLyHrS2fo8DkFETr5WIU/view?usp=sharing' title='Google Drive'> Nestle India -Historical Stock Price Data

# %% [markdown]
# For description of the dataset: <br>
#
# Click here: <br>
# <a href='https://docs.google.com/document/d/1O12MOt8O7qsgyRIt0XzBnlcbzBJCRcksDz1fU2EGu3k/edit?usp=sharing' title='Google Drive'> Description

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <p style='margin-top:1em; text-align:left'>
# <b># Task: </b></p>
# <p style='margin-left:1em;'>
# - The Task is to train the model to predict the Close Price (taken from here itself as test data) building a model using LINEAR REGRESSION. <br>
# </p>
# </span>
# </div>

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#70A0AF; color:#FFFFFF'>
# <span>
# <p style='margin-top:1em; text-align:left'>
# <b># Important: </b></p>
# <p style='margin-left:1em;'>
# - The tasks are given to guide the flow and practice, Few tasks can also be considered optional if there is no need or any other case <br>
# - It is always encouraged to add or modify the list or flow given here. <br>
# - Also, Not only the results, a few other factors like Visualization, Inferences, Reasons, Probabilities and Implementations are equally important. <br>
# - Please make sure the reasons or conclusions for the plots, results and summaries are mentioned in your own way. Add a natural comprehension to it thinking from a real time perspective <br>
# - Its always encouraged to make this process a way of conveying a story as engaging as possible
# </p>
# </span>
# </div>

# %% [markdown]
# ##  <mark><span  style= "font-family: Times New Roman">Import necessary libraries </span> </mark> <a class="anchor" id="Import necessary libraries"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('nestle.csv')
df
# Out:
#                 Date  Open Price  High Price  Low Price  Close Price  \
# 0      21-April-2022    18150.00    18572.95   17772.90     18205.80
# 1      20-April-2022    18100.10    18415.00   18017.15     18313.70
# 2      19-April-2022    18470.05    18718.00   17845.60     17943.15
# 3      18-April-2022    18294.50    18684.50   18294.50     18549.85
# 4      13-April-2022    18371.20    18549.30   18248.25     18343.90
# ...              ...         ...         ...        ...          ...
# 2548  6-January-2012     4114.00     4160.00    4076.00      4143.25
# 2549  5-January-2012     4118.00     4126.90    4080.00      4101.85
# 2550  4-January-2012     4100.00     4125.00    4081.40      4120.60
# 2551  3-January-2012     4061.00     4110.10    4060.10      4095.35
# 2552  2-January-2012     4139.90     4139.90    4044.00      4070.35
#
#                WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
df.head()
# Out:
#             Date  Open Price  High Price  Low Price  Close Price  \
# 0  21-April-2022    18150.00    18572.95   17772.90     18205.80
# 1  20-April-2022    18100.10    18415.00   18017.15     18313.70
# 2  19-April-2022    18470.05    18718.00   17845.60     17943.15
# 3  18-April-2022    18294.50    18684.50   18294.50     18549.85
# 4  13-April-2022    18371.20    18549.30   18248.25     18343.90
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  18130.183442          4590           1770            83217542.0
# 1  18295.559071          6069           1321           111035748.0
# 2  18355.093320          2904            716            53303191.0
# 3  18511.224599          1496            586            27692792.0
# 4  18388.967826          1150            550            21147313.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                 950.0                      20.70           800.05
# ...

# %%
df.tail()
# Out:
#                 Date  Open Price  High Price  Low Price  Close Price  \
# 2548  6-January-2012      4114.0      4160.0     4076.0      4143.25
# 2549  5-January-2012      4118.0      4126.9     4080.0      4101.85
# 2550  4-January-2012      4100.0      4125.0     4081.4      4120.60
# 2551  3-January-2012      4061.0      4110.1     4060.1      4095.35
# 2552  2-January-2012      4139.9      4139.9     4044.0      4070.35
#
#               WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 2548  4129.486321          3107            444            12830314.0
# 2549  4106.848723          1018            270             4180772.0
# 2550  4105.106055          2857            247            11728288.0
# 2551  4091.474315          5003            886            20469646.0
# 2552  4085.640979          7760           1132            31704574.0
#
#       Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# ...

# %%
df.shape
# Out:
# (2553, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2553 entries, 0 to 2552
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2553 non-null   object
#  1   Open Price                 2553 non-null   float64
#  2   High Price                 2553 non-null   float64
#  3   Low Price                  2553 non-null   float64
#  4   Close Price                2553 non-null   float64
#  5   WAP                        2553 non-null   float64
#  6   No.of Shares               2553 non-null   int64
#  7   No. of Trades              2553 non-null   int64
#  8   Total Turnover (Rs.)       2553 non-null   float64
#  9   Deliverable Quantity       2551 non-null   float64
#  10  % Deli. Qty to Traded Qty  2551 non-null   float64
#  11  Spread High-Low            2553 non-null   float64
#  12  Spread Close-Open          2553 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Open Price    High Price     Low Price   Close Price           WAP  \
# count   2553.000000   2553.000000   2553.000000   2553.000000   2553.000000
# mean    9338.023188   9429.710419   9226.855934   9324.960556   9327.503179
# std     4940.554627   4986.783271   4878.971233   4932.776537   4929.373727
# min     3970.000000   3995.000000   3930.000000   3942.450000   3936.768632
# 25%     5391.000000   5445.000000   5327.200000   5383.500000   5385.347807
# 50%     6804.000000   6868.900000   6747.300000   6809.950000   6813.150538
# 75%    13299.950000  13690.950000  12850.000000  13455.450000  13387.505382
# max    20452.000000  20599.950000  20243.800000  20439.450000  20417.372402
#
#         No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# count    2553.000000    2553.000000          2.553000e+03
# mean     5521.380337    1004.099491          4.761923e+07
# std     10416.942384    1137.547557          8.502888e+07
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%B-%Y')

# %%
df.corr()
# Out:
#                                Date  Open Price  High Price  Low Price  \
# Date                       1.000000    0.916166    0.916307   0.916191
# Open Price                 0.916166    1.000000    0.999722   0.999701
# High Price                 0.916307    0.999722    1.000000   0.999610
# Low Price                  0.916191    0.999701    0.999610   1.000000
# Close Price                0.916351    0.999490    0.999793   0.999761
# WAP                        0.916403    0.999693    0.999879   0.999858
# No.of Shares              -0.061823   -0.076134   -0.073740  -0.078191
# No. of Trades              0.130994    0.155587    0.162156   0.150214
# Total Turnover (Rs.)       0.185630    0.191480    0.194465   0.188937
# Deliverable Quantity      -0.084476   -0.093000   -0.092403  -0.093886
# % Deli. Qty to Traded Qty -0.300251   -0.246738   -0.248603  -0.245208
# Spread High-Low            0.567792    0.616536    0.627006   0.604996
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,linecolor='blue')
# Out:
# <Axes: >

# %%
sns.pairplot(data=df);

# %%
df.hist(bins=50,figsize=(15,10));

# %%
sns.distplot(df['Close Price'],hist=True,color='Blue');

# %%
# Exclude the 'Date' column from numeric columns
num_col = [col for col in df.columns if col != 'Date' and df[col].dtype != 'object']

plt.figure(figsize=(20, 15))
plotnumber = 1

for column in num_col:
    if plotnumber <= 13:
        ax = plt.subplot(3, 5, plotnumber)
        sns.histplot(df[column], color='black', kde=True)
        plt.xlabel(column)
        plt.ylabel('Frequency')

    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
df.isnull().sum()
# Out:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         2
# % Deli. Qty to Traded Qty    2
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Open Price',data=df,orient='h');

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='High Price',data=df,orient='h');

# %% [markdown]
# <span style="font: red"> Here, You can mention the reasons or the advantages and disadvantages, ease and complications, favourable things and degree of difficulty in applying Linear Regression to the data.  </span>

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Low Price',data=df,orient='h');

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='Close Price',data=df,orient='h');

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='WAP',data=df,orient='h');

# %%
df['Day']=df['Date'].dt.weekday
df['Month']=df['Date'].dt.month
df['Year']=df['Date'].dt.year

# %%
df.drop('Date',axis=1,inplace=True)
df['Day'].value_counts()
# Out:
# Day
# 1    513
# 2    512
# 3    509
# 0    509
# 4    498
# 5      9
# 6      3
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#    Open Price  High Price  Low Price  Close Price           WAP  No.of Shares  \
# 0    18150.00    18572.95   17772.90     18205.80  18130.183442          4590
# 1    18100.10    18415.00   18017.15     18313.70  18295.559071          6069
# 2    18470.05    18718.00   17845.60     17943.15  18355.093320          2904
# 3    18294.50    18684.50   18294.50     18549.85  18511.224599          1496
# 4    18371.20    18549.30   18248.25     18343.90  18388.967826          1150
# 5    18339.00    18497.00   18216.30     18430.00  18390.222000          2000
# 6    18499.00    18518.35   18225.00     18422.70  18385.862360           712
# 7    18180.00    18500.00   18101.00     18431.10  18361.677527          1197
# 8    18198.60    18245.95   17986.75     18175.55  18131.799564           918
# 9    17900.00    18255.35   17871.20     18207.60  18096.243542           813
#
#    No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# ...

# %%
df.tail(10)
# Out:
#       Open Price  High Price  Low Price  Close Price          WAP  \
# 2543     4060.00     4069.95     3949.0      3957.55  4001.764969
# 2544     4080.05     4100.00     4061.0      4068.75  4082.916325
# 2545     4096.00     4124.95     4096.0      4108.40  4116.043885
# 2546     4139.00     4160.00     4080.0      4093.40  4109.409150
# 2547     4099.80     4146.95     4099.8      4125.00  4128.345238
# 2548     4114.00     4160.00     4076.0      4143.25  4129.486321
# 2549     4118.00     4126.90     4080.0      4101.85  4106.848723
# 2550     4100.00     4125.00     4081.4      4120.60  4105.106055
# 2551     4061.00     4110.10     4060.1      4095.35  4091.474315
# 2552     4139.90     4139.90     4044.0      4070.35  4085.640979
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 2543          6480           1024            25931437.0                2893.0
# 2544          3167            498            12930596.0                2235.0
# ...

# %%
days = {0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4: 'Friday',5:'Saturday',6:'Sunday'}
df['Day'] = df['Day'].map(days)

# %%
df1=df.groupby('Year')['No. of Trades'].sum()
df1
# Out:
# Year
# 2012    128129
# 2013    181198
# 2014    227595
# 2015    464161
# 2016    228811
# 2017    144073
# 2018    177668
# 2019    193401
# 2020    457517
# 2021    296816
# 2022     64097
# Name: No. of Trades, dtype: int64

# %%
plt.pie(df1,labels=df['Year'].unique(),autopct='%1.2f%%');
plt.title('no. of trades')
# Out:
# Text(0.5, 1.0, 'no. of trades')

# %%
df2 = df.groupby('Day')['No. of Trades'].sum().reset_index()
df2.head(10)
# Out:
#          Day  No. of Trades
# 0     Friday         528457
# 1     Monday         484210
# 2   Saturday           2011
# 3     Sunday            933
# 4   Thursday         519870
# 5    Tuesday         490994
# 6  Wednesday         536991

# %%
plt.figure(figsize=(10,6))
plt.pie(dw['No. of Trades'],labels= df2['Day'],autopct='%1.2f%%');

# %%
df2 = df.groupby('Day')['High Price'].sum().reset_index()
df2.head(10)
# Out:
#          Day  High Price
# 0     Friday  4671316.70
# 1     Monday  4801443.15
# 2   Saturday    67300.55
# 3     Sunday    27766.95
# 4   Thursday  4823236.60
# 5    Tuesday  4842013.20
# 6  Wednesday  4840973.55

# %%
plt.figure(figsize=(10,8))
plt.pie(df2['High Price'],labels= df2['Day'],autopct='%1.2f%%');

# %%
sns.lineplot(data=df, x="Year", y="No. of Trades");

# %%
sns.lineplot(data=df, x="Year", y="High Price");

# %%
sns.lineplot(data=df, x="Month", y="No. of Trades");

# %%
sns.lineplot(data=df,x='Month',y='High Price');

# %%
df.columns
# Out:
# Index(['Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP'], dtype='object')

# %%
X=df[['WAP']]
y=df['Close Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.9998572935940231

# %%
lr.score(X_test,y_test)
# Out:
# 0.9998365410513401

# %%
lr.coef_
# Out:
# array([1.00045917])

# %%
lr.intercept_
# Out:
# -7.890221724752337

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame
plt.figure(figsize=(12, 10))
sns.regplot(x='WAP', y='Close Price', data=df)
plt.xlabel('WAP')
plt.ylabel('Close Price')
plt.title('Scatter Plot with Regression Line')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
sns.jointplot(x='WAP', y='Close Price', data=df, kind='reg', height=10)
plt.show()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn import metrics
print("R score",metrics.r2_score(y_test,y_pred))
print("MSE = ", metrics.mean_squared_error(y_test,y_pred))
# Out:
# R score 0.9998365410513401
# MSE =  3821.9935122412194

# %%
lr_diff=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred})
lr_diff.head(5)
# Out:
#       Actual Value  Predicted Value
# 249       17086.25     17111.878458
# 63        19328.80     19360.946506
# 1770       7045.10      7042.596232
# 1835       6317.25      6278.206706
# 2428       4509.75      4502.130628

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

scores = cross_val_score(lr, X_train, y_train, scoring='r2', cv=5)
scores
# Out:
# array([0.99984708, 0.99986014, 0.99988188, 0.99984267, 0.99985233])

# %%
accuracy_fold=np.mean(abs(scores))
accuracy_fold
# Out:
# 0.9998568224000902

# %%
X=df.drop('Close Price',axis=1)
y=df['Close Price']

# %%
from sklearn.preprocessing import StandardScaler
# define StandScaler scaler
scaler = StandardScaler()
# transform data
scaled = scaler.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(scaled,y,test_size=0.2,random_state=42)

lr = LinearRegression().fit(X_train, y_train)
y_pred=lr.predict(X_test)

# %%
lr.score(X_train, y_train)
# Out:
# 0.9998900472039419

# %%
lr.score(X_test, y_test)
# Out:
# 0.9998729181379519

# %%
lr_diff=pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred})
lr_diff.head()
# Out:
#       Actual Value  Predicted Value
# 1949       4812.95      4814.966674
# 637       13945.10     13955.371596
# 2150       5101.50      5101.681874
# 393       16098.90     16024.177325
# 1023       7850.55      7863.032807

# %%
y_pred = lr.predict(X_test)
print("R score",metrics.r2_score(y_test,y_pred))
print("MSE = ", metrics.mean_squared_error(y_test,y_pred))
# Out:
# R score 0.9998729181379519
# MSE =  3109.1778676987237

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score

# %%
#MAE,MAPE,accuracy
print("mean_absolute_error is",mean_absolute_error(y_test,y_pred))
print("error percentage is",mean_absolute_percentage_error(y_test,y_pred))
print("accuracy is",1-mean_absolute_percentage_error(y_test,y_pred))
# Out:
# mean_absolute_error is 34.59853605707103
# error percentage is 0.0035696611010896306
# accuracy is 0.9964303388989104

# %%
#MSE, RMSE
print("mean_squared_error is",mean_squared_error(y_test,y_pred))
print("root mean squared error is: ", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mean_squared_error is 3109.1778676987237
# root mean squared error is:  55.76000240045479

# %%
#R2 score
print("r2_score is",r2_score(y_test,y_pred))
# Out:
# r2_score is 0.9998729181379519

# %% [markdown]
# ###### * R-squared on the Training Set:This indicates that about 99.99% of the variance in the 'Close Price' is explained by the model, showcasing an excellent fit to the training data.
#
# ###### * R-squared on the Testing Set:The R-squared value on the testing set is approximately 0.9999.This demonstrates that the model maintains a high level of explanatory power when applied to new, unseen data.
#
# ###### * Mean Squared Error (MSE):An MSE of 3109.18 suggests that, on average, the squared differences between the model's predictions and the actual values are relatively small.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ##### * The linear regression model appears to be highly accurate, explaining a significant proportion of the variance in the 'Close Price'.
# ##### * The model generalizes well to new data, as evidenced by the consistency in R-squared values between the training and testing sets.
# ##### * The Mean Squared Error, while providing a measure of prediction accuracy, should be considered in the context of the scale and distribution of the 'Close Price'.
