# %% [markdown]
# # <div class="alert alert-block alert-info"> <span style="font-family: Times New Roman">Descriptive Statistics Assignment </span> </div>

# %% [markdown]
# ###### Note:
# <div class="alert alert-block alert-danger"> <span style="font-family: Times New Roman">
#     - Kindly use this notebook to solve the programming problems. <br>
#     - Submit assignments with .ipynb file extension.<br>
# - Kindly write down the explanations/insights for the graphs.<br>
# - Kindly use comments or markdowns to explain logic behind the codes, approach to solve the problem.</span></div>

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <p style='margin-top:1em; text-align:left'>
# </p>
# <p style='margin-left:1em;'>
# <b>The below-given data is of two batsmen from which the captain has to select one batsman. As a captain, I need a batsman whose performance is stable in England. A test series is happening in England during winter. Use Descriptive statistics to select one batsman who can probably perform better than the other. Please give proper reasoning behind your selection, like why you have chosen the particular batsman supported by statistic outputs. You have to show your numerical findings with the help of Python code, and a theoretical interpretation also is given to support your conclusion.
#     </b></p>
#
# ![Discriptive%20Stats.png](attachment:Discriptive%20Stats.png)
#
# </span>
# </div>

# %% [markdown]
# ##  <mark><span  style= "font-family: Times New Roman">Import necessary libraries</span> </mark> <a class="anchor" id="Import_necessary_libraries"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##  <mark><span  style= "font-family: Times New Roman">View the data</span> </mark> <a class="anchor" id="Import_necessary_libraries"></a>

# %%
import pandas as pd
data = {'Batsman A': [56, 19, 0, 68, 16, 67, 85, 101, 78],
        'Batsman B': [60, 58, 38, 71, 69, 66, 68, 41, 67],
        'Temperature' : [31, 33, 30, 35, 34, 15, 10, 7, 11]}
df5 = pd.DataFrame(data)
print()
df5
# Out:
#    Batsman A  Batsman B  Temperature
# 0         56         60           31
# 1         19         58           33
# 2          0         38           30
# 3         68         71           35
# 4         16         69           34
# 5         67         66           15
# 6         85         68           10
# 7        101         41            7
# 8         78         67           11

# %%
import numpy as np
a_mean = np.mean(df['Batsman A'])
a_median = np.median(df['Batsman A'])
a_std = np.std(df['Batsman A'])
a_cv = a_std / a_mean
print("Batsman A - Mean: {:.2f}, Median: {:.2f}, Standard Deviation: {:.2f}, Coefficient of Variation: {:.2f}".format(a_mean, a_median, a_std, a_cv))
print('Temperature - Mean:', df['Temperature'].mean())
print('Temperature - Median:', df['Temperature'].median())
print('Temperature - Standard Deviation:', df['Temperature'].std())
print('Temperature - Coefficient of Variation:', df['Temperature'].std() / df['Temperature'].mean())
# Out:
# Batsman A - Mean: 58.67, Median: 67.00, Standard Deviation: 27.58, Coefficient of Variation: 0.47
# Temperature - Mean: 22.88888888888889
# Temperature - Median: 30.0
# Temperature - Standard Deviation: 11.783934449542356
# Temperature - Coefficient of Variation: 0.514832087601365

# %%
import numpy as np
b_mean = np.mean(df['Batsman B'])
b_median = np.median(df['Batsman B'])
b_std = np.std(df['Batsman B'])
b_cv = b_std / b_mean
print("Batsman B - Mean: {:.2f}, Median: {:.2f}, Standard Deviation: {:.2f}, Coefficient of Variation: {:.2f}".format(b_mean, b_median, b_std, b_cv))
print('Temperature - Mean:', df['Temperature'].mean())
print('Temperature - Median:', df['Temperature'].median())
print('Temperature - Standard Deviation:', df['Temperature'].std())
print('Temperature - Coefficient of Variation:', df['Temperature'].std() / df['Temperature'].mean())
# Out:
# Batsman B - Mean: 59.78, Median: 66.00, Standard Deviation: 11.54, Coefficient of Variation: 0.19
# Temperature - Mean: 22.88888888888889
# Temperature - Median: 30.0
# Temperature - Standard Deviation: 11.783934449542356
# Temperature - Coefficient of Variation: 0.514832087601365

# %% [markdown]
# ##  <mark><span  style= "font-family: Times New Roman">Data preprocessing</span> </mark> <a class="anchor" id="Import_necessary_libraries"></a>

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <p style='margin-top:1em; text-align:left'>
# </p>
# <p style='margin-left:1em;'>
# </p><br>
#
#   1. Third match score of Batsman-1 was mistakenly noted as 0. Kindly replace the value with the mean of earlier matches as it is not known.Round the calculated mean to the nearest integer. <br>
#
# 2. Create a new feature in the dataframe naming 'weather' <br>
#
#    a. Column should have 'Warm' if the temperature on the match day is greater than the mean of the temperatures.  <br>
#    b. Column should have 'Cool' if the temperature on the match day is lesser than the mean of the temperatures.  <br>
# </span>
# </div>

# %%
df2 = df5
mean = round(sum(df['Batsman A'][:2])/2)
df5['Batsman A'][2] = mean
print()
df2
# Out:
#    Batsman A  Batsman B  Temperature
# 0         56         60           31
# 1         19         58           33
# 2         38         38           30
# 3         68         71           35
# 4         16         69           34
# 5         67         66           15
# 6         85         68           10
# 7        101         41            7
# 8         78         67           11

# %%
temp_data = [31, 33, 30, 35, 34, 15, 10, 7, 11]
temp_mean = sum(temp_data)/len(temp_data)
weather = ['Warm' if temp > temp_mean else 'Cool' for temp in temp_data]
df3 = pd.DataFrame({'Batsman A': [56, 19, 38, 68, 16, 67, 85, 101, 78], 'Batsman B': [60, 58, 38, 71, 69, 66, 68, 41, 67], 'Temperature': temp_data, 'Weather': weather})
print()
df3
# Out:
#    Batsman A  Batsman B  Temperature Weather
# 0         56         60           31    Warm
# 1         19         58           33    Warm
# 2         38         38           30    Warm
# 3         68         71           35    Warm
# 4         16         69           34    Warm
# 5         67         66           15    Cool
# 6         85         68           10    Cool
# 7        101         41            7    Cool
# 8         78         67           11    Cool

# %% [markdown]
# ##  <mark><span  style= "font-family: Times New Roman">Perform EDA</span> </mark> <a class="anchor" id="Import_necessary_libraries"></a>

# %% [markdown]
# ### Visualize the evidences

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(data=df3[['Batsman A', 'Batsman B']])
plt.xlabel('Batsmen')
plt.ylabel('Scores')
plt.title('Boxplot of Scores for Batsman A and Batsman B')
plt.show()

# %%
sns.scatterplot(data=df3, x='Temperature', y='Batsman A', label='Batsman A')
sns.scatterplot(data=df3, x='Temperature', y='Batsman B', label='Batsman B')
plt.xlabel('Temperature')
plt.ylabel('Scores')
plt.title('Scatter plot of Scores vs Temperature')
plt.legend()
plt.show()

# %%
sns.countplot(data=df3, x='Weather')
plt.xlabel('Weather')
plt.ylabel('Count')
plt.title('Bar plot of Matches Played in Warm and Cool Weather')
plt.show()

# %% [markdown]
# ##  <mark><span  style= "font-family: Times New Roman">Conclusion</span> </mark> <a class="anchor" id="Import_necessary_libraries"></a>

# %%
#Batsman B has a higher mean score (59.78) compared to Batsman A (54.44), which indicates that Batsman B is likely to score more runs on average.

#1. The standard deviation of Batsman B's scores (11.54) is lower than that of Batsman A (32.83), which indicates that Batsman B's performance is more consistent.

#2. The coefficient of variation (CV) for Batsman B (0.19) is lower than that of Batsman A (0.60), which indicates that Batsman B's performance is less variable relative to the mean.

#3. The weather data indicates that the temperature during the test series is around the mean temperature, which means that both batsmen are likely to perform similarly in terms of weather conditions. 

#4. Additionally, the boxplots show that Batsman B's scores are generally higher and less variable than Batsman A's scores.
